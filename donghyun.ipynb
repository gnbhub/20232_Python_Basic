# %% [markdown]
# <a href="https://colab.research.google.com/github/gnbhub/20232_Python_Basic/blob/master/donghyun.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Hello, world!')
# Out:
# Hello, world!
